# %% [markdown]
# # Recommender with subset of item/user attributes

# %% [markdown]
# ## Introduction
#
# In this notebook, we develop a personalized recommender system for tech products using a subset of user and item attributes. Starting with preprocessed data—including user id,age  and product id and price—we construct a two-tower neural network model that learns to match users with relevant items.
#
# The pipeline includes steps such as:
#
# * Preparing positive and negative interaction samples
#
# * Feature preprocessing (encoding and scaling)
#
# * Building and training the recommendation model
#
# * Generating and displaying recommendations for diverse user personalities
#
# * Evaluating the model’s predictive performance using a holdout set
#
# This approach allows us to build a recommender that not only predicts user preferences accurately but also adapts to varying user profiles and product characteristics.

# %% [markdown]
# ## Installations and Imports

# %%
# Install required packages
# !pip install -q tensorflow scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras import layers, Model
from pprint import pprint
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Preparation and Holdout Set Creation for Recommender Training

# %% [markdown]
# In this phase, we begin building the recommender system using a subset of user and item attributes. The user, item, and interaction data are first loaded from the previously generated CSV files: users.csv, items.csv, and user_product_rating_matrix.csv. These files were created during the earlier stage of data generation and represent our chosen domain — tech products.
#
# The interaction matrix is reshaped into a user-item-label format, focusing solely on positive interactions (i.e., where a user has meaningfully interacted with a product). To train and evaluate the model, we randomly split the positive interactions into 80% training and 20% holdout sets.
#
# The holdout set is crucial as it allows us to test the recommender's ability to predict items that a user has already interacted with — simulating how well the model can recover known preferences. This step ensures that our evaluation is grounded in realistic scenarios and supports the development of a more effective recommendation strategy.

# %%
users = pd.read_csv('users.csv')


items = pd.read_csv('items.csv')
ratings_df = pd.read_csv('user_product_rating_matrix.csv')

# Create user-item pairs for training based on ratings_df
interactions_df = ratings_df.melt(id_vars=['user_id'], var_name='item_id', value_name='label')
interactions_positve=interactions_df[interactions_df['label'] == 1]

# %%
from sklearn.model_selection import train_test_split

# Shuffle and split interactions (assuming all are positive)
interactions_shuffled = interactions_positve.sample(frac=1, random_state=42).reset_index(drop=True)

# Split into 80% train, 20% holdout
interactions_train, interactions_holdout = train_test_split(
    interactions_shuffled,
    test_size=0.2,
    random_state=42
)

# Optional: reset indices
interactions = interactions_train.reset_index(drop=True)
interactions_holdout = interactions_holdout.reset_index(drop=True)

# %%
print(users.shape)
print(items.shape)
print(interactions.shape)
print(interactions_holdout.shape)
# Out:
# (10000, 4)
# (1000, 5)
# (773028, 3)
# (193258, 3)

# %% [markdown]
# ## Negative Sampling for Balanced Interaction Modeling

# %% [markdown]
# To improve the robustness of our recommender system and train a model that can effectively distinguish between relevant and irrelevant items, we implement negative sampling.
#
# In real-world scenarios, users interact with only a small fraction of available products — leaving most items unobserved. Treating all non-interactions as negative signals can lead to bias. To address this, we sample a manageable and representative set of negative examples.
#
# Specifically, we:
#
# * Extract all negative user-item pairs (label = 0).
#
# * Shuffle these globally to ensure randomness.
#
# * Limit the number of negatives per user by selecting the top 100 for each user.
#
# * Combine these negatives with the previously extracted positive interactions (label = 1).
#
# This balanced dataset of positive and negative interactions allows us to train models that better understand user preferences and make more accurate predictions.

# %%
import pandas as pd
from tqdm import tqdm

# Step 1: Filter to only negative samples
negatives = interactions_df[interactions_df['label'] == 0]

# Step 2: Shuffle the negatives globally
negatives = negatives.sample(frac=1, random_state=42).reset_index(drop=True)

# Step 3: For each user, take the first 100 negatives
neg_samples = (
    negatives.groupby('user_id', group_keys=False)
    .head(100)
)

# Step 4: Mark original interactions (positives) with label = 1, if not already
interactions['label'] = 1

# Step 5: Combine positives and sampled negatives
enhanced_interactions = pd.concat([interactions, neg_samples], ignore_index=True)
interactions=enhanced_interactions

# %%
# new shape with also 100 extra non interactions per user
interactions.shape
# Out:
# (1773028, 3)

# %% [markdown]
# ## Preprocessing User and Item Attributes for Model Input

# %% [markdown]
# Before feeding the data into the recommender model, we preprocess user and item attributes to ensure they are in a format suitable for machine learning algorithms.
#
# We begin by merging relevant user (e.g., age) and item (e.g., price) attributes into the interaction dataset. Then, we apply the following preprocessing steps:
#
# * Label Encoding: We convert the categorical identifiers (user_id and item_id) into numerical representations using LabelEncoder. This transformation is essential for embedding layers in recommendation models.
#
# * Feature Scaling: Numerical features like user age and product price are scaled using MinMaxScaler to normalize their values between 0 and 1. This prevents features with larger ranges from dominating the learning process.
#
# These steps ensure that both categorical and numerical attributes are efficiently utilized by the model, leading to improved learning and better generalization.

# %%
# Merge age and price
interactions = interactions.merge(users, on='user_id')
interactions = interactions.merge(items, on='item_id')

from sklearn.preprocessing import LabelEncoder, MinMaxScaler

user_encoder = LabelEncoder()
item_encoder = LabelEncoder()

interactions['user_encoded'] = user_encoder.fit_transform(interactions['user_id'])
interactions['item_encoded'] = item_encoder.fit_transform(interactions['item_id'])

# Scale numerical features
scaler_age = MinMaxScaler()
scaler_price = MinMaxScaler()

interactions['age_scaled'] = scaler_age.fit_transform(interactions[['age']])
interactions['price_scaled'] = scaler_price.fit_transform(interactions[['price']])

# %% [markdown]
# ## Building a Two-Tower Neural Network Recommender

# %% [markdown]
# In this section, we implement a two-tower neural network recommender that learns separate representations for users and items before combining them to predict interactions.
#
# The model is structured as follows:
#
# * User Tower: Processes user-specific inputs — a unique user ID and their scaled age. The user ID is passed through an embedding layer, flattened, and then concatenated with the age input. This merged vector is then transformed via a dense layer.
#
# * Item Tower: Mirrors the user tower but operates on item-specific inputs — item ID and scaled price. The embedded item ID and item price are similarly combined and passed through a dense layer.
#
# * Interaction Layer: The outputs of both towers (user and item representations) are combined using a dot product, which captures their similarity. A sigmoid activation then predicts the probability of interaction (i.e., whether the user would interact with the item).
#
# We compile the model using binary cross-entropy loss and the Adam optimizer, training it over 5 epochs with a batch size of 64.
#
# This two-tower architecture enables efficient learning of user-item relationships and can scale to large datasets, making it a strong baseline for personalized recommendation.

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, Input

embedding_dim = 32

# Inputs
user_id_input = Input(shape=(), name='user_id', dtype=tf.int32)
user_age_input = Input(shape=(1,), name='user_age', dtype=tf.float32)

item_id_input = Input(shape=(), name='item_id', dtype=tf.int32)
item_price_input = Input(shape=(1,), name='item_price', dtype=tf.float32)

# User tower
user_embedding = layers.Embedding(len(user_encoder.classes_), embedding_dim)(user_id_input)
user_embedding = layers.Flatten()(user_embedding)
user_concat = layers.Concatenate()([user_embedding, user_age_input])
user_vector = layers.Dense(64, activation='relu')(user_concat)

# Item tower
item_embedding = layers.Embedding(len(item_encoder.classes_), embedding_dim)(item_id_input)
item_embedding = layers.Flatten()(item_embedding)
item_concat = layers.Concatenate()([item_embedding, item_price_input])
item_vector = layers.Dense(64, activation='relu')(item_concat)

# Dot product
dot_product = layers.Dot(axes=1)([user_vector, item_vector])
output = layers.Activation('sigmoid')(dot_product)

# Compile
model = Model(inputs=[user_id_input, user_age_input, item_id_input, item_price_input], outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Build input
X = {
    'user_id': interactions['user_encoded'].values,
    'user_age': interactions['age_scaled'].values,
    'item_id': interactions['item_encoded'].values,
    'item_price': interactions['price_scaled'].values
}
y = interactions['label'].values

model.fit(X, y, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 27704/27704 ━━━━━━━━━━━━━━━━━━━━ 80s 3ms/step - accuracy: 0.6810 - loss: 0.6121
# Epoch 2/5
# 27704/27704 ━━━━━━━━━━━━━━━━━━━━ 79s 3ms/step - accuracy: 0.7711 - loss: 0.5566
# Epoch 3/5
# 27704/27704 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - accuracy: 0.7723 - loss: 0.5554
# Epoch 4/5
# 27704/27704 ━━━━━━━━━━━━━━━━━━━━ 77s 3ms/step - accuracy: 0.7724 - loss: 0.5554
# Epoch 5/5
# 27704/27704 ━━━━━━━━━━━━━━━━━━━━ 83s 3ms/step - accuracy: 0.7732 - loss: 0.5555

# %% [markdown]
# ## Personalized Recommendation For Users

# %% [markdown]
# To enable personalized suggestions, we implemented a function that provides the top-N most relevant product recommendations for a specific user, based on the trained two-tower model.
#
# The function follows these steps:
#
# 1. User Feature Extraction: Retrieves and encodes the user's ID and scales their age using the fitted scaler.
#
# 2. Candidate Item Pool: Considers all available items, excluding those the user has already interacted with positively.
#
# 3. Input Preparation: Constructs model inputs by replicating the user features for all remaining candidate items.
#
# 4. Prediction: The model computes interaction scores (likelihood of preference) for each user-item pair.
#
# 5. Ranking: The top-N items with the highest scores are selected as recommendations.
#
# 6. Result Formatting: For each recommended item, we provide relevant metadata (e.g., description, price, type, and features), along with the predicted score.
#
# This function supports flexible top-N queries and enables us to evaluate or demonstrate the recommender’s output for individual users, highlighting its personalization capabilities

# %%
def recommend_for_user(user_id, top_n=5):
    # Get user encoded index and scaled age
    user_idx = user_encoder.transform([user_id])[0]
    user_row = users[users['user_id'] == user_id].iloc[0]
    user_age_scaled = scaler_age.transform([[user_row['age']]])[0][0]

    # All item data
    all_item_ids = items['item_id'].values
    all_item_indices = item_encoder.transform(all_item_ids)
    item_prices = items['price'].values
    item_prices_scaled = scaler_price.transform(item_prices.reshape(-1, 1)).flatten()

    # Remove already interacted items
    interacted_items = interactions[
        (interactions['user_id'] == user_id) & (interactions['label'] == 1)
    ]['item_id'].values
    interacted_indices = item_encoder.transform(interacted_items)

    mask = ~np.isin(all_item_indices, interacted_indices)
    item_indices = all_item_indices[mask]
    item_ids = all_item_ids[mask]
    item_prices_scaled = item_prices_scaled[mask]

    # Prepare model input
    user_id_array = np.full_like(item_indices, user_idx)
    user_age_array = np.full_like(item_prices_scaled, user_age_scaled)

    # Predict scores
    predictions = model.predict({
        'user_id': user_id_array,
        'user_age': user_age_array,
        'item_id': item_indices,
        'item_price': item_prices_scaled
    }, verbose=0).flatten()

    # Select top N
    top_idxs = predictions.argsort()[-top_n:][::-1]
    top_item_ids = item_ids[top_idxs]
    top_scores = predictions[top_idxs]

    # Merge and format output
    recommended = []
    for item_id, score in zip(top_item_ids, top_scores):
        item_row = items[items['item_id'] == item_id].iloc[0]
        rec = {
            'user_id': user_row['user_id'],
            'user_age': user_row['age'],
            'user_profession': user_row.get('profession', 'N/A'),
            'user_personality': user_row.get('personality', 'N/A'),
            'item_id': item_row['item_id'],
            'item_type': item_row.get('product_type', 'N/A'),
            'item_description': item_row.get('description', 'N/A'),
            'item_price': item_row['price'],
            'item_features': item_row.get('features', 'N/A'),
            'score': float(score)
        }
        recommended.append(rec)

    return recommended

# %%
# print recommendations for a random user
pprint(recommend_for_user('bud_0002', top_n=3))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'With noise cancellation and wireless connectivity, this '
#                       'headphones is great for travel. Perfect for music '
#                       'lovers, it delivers top-tier functionality.',
#   'item_features': 'Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0755',
#   'item_price': np.float64(43.5),
#   'item_type': 'headphones',
#   'score': 0.9996224641799927,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0002',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'With wireless connectivity and noise cancellation, this '
#                       'headphones is great for travel. Perfect for music '
#                       'lovers, it delivers top-tier functionality.',
#   'item_features': 'Bluetooth 5.0, Over-ear design, Noise cancellation, Fast '
#                    'charging',
#   'item_id': 'item_0341',
#   'item_price': np.float64(46.06),
#   'item_type': 'headphones',
#   'score': 0.9976105690002441,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0002',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'This laptop features long battery life and advanced '
#                       'cooling system, designed for business professionals. It '
#                       'is built for performance, offering reliable performance '
#                       'and user comfort.',
#   'item_features': 'Fast charging, Bluetooth 5.0, Touchscreen, Expandable '
#                    'storage',
#   'item_id': 'item_0342',
#   'item_price': np.float64(751.33),
#   'item_type': 'laptop',
#   'score': 0.5,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0002',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'}]

# %% [markdown]
# ## Exploring Recommendations Across Personality Types

# %% [markdown]
# To better understand how the recommender adapts to different user profiles, we generated indicative recommendations for a sample of users from each personality type.
#
# For each personality group, we randomly selected up to three users, and for each user, we retrieved the top-5 personalized recommendations using our trained model. These recommendations were then printed along with relevant user and item details, offering insights into:
#
# * The diversity and relevance of recommended tech products.
#
# * How user attributes, such as age and personality, influence the system’s output.
#
# * Potential patterns or differences in recommendations across personality types.
#
# This qualitative step serves as an initial diagnostic of model behavior, helping us assess whether personalization is occurring meaningfully across segments before moving on to quantitative evaluation.

# %%
import random
from pprint import pprint

def recommend_for_representative_users(users_df, top_n=5, users_per_personality=3):
    personalities = users_df['personality'].unique()

    for personality in personalities:
        print(f"\n Personality: {personality}")
        personality_users = users_df[users_df['personality'] == personality]['user_id'].tolist()

        if len(personality_users) < users_per_personality:
            selected_users = personality_users
        else:
            selected_users = random.sample(personality_users, users_per_personality)

        for user_id in selected_users:
            print(f"\n Recommendations for user: {user_id}")
            recs = recommend_for_user(user_id, top_n=top_n)
            pprint(recs)

# %%
# print recommedations for 3 users per personality
recommend_for_representative_users(users, top_n=5, users_per_personality=3)
# Out:
#  Personality: Tech Enthusiast
#
#  Recommendations for user: tec_0348
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'This laptop features advanced cooling system and '
#                       'AI-powered processor, designed for gamers. It is built '
#                       'for performance, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0849',
#   'item_price': np.float64(483.54),
#   'item_type': 'laptop',
#   'score': 0.9993810653686523,
#   'user_age': np.int64(35),
#   'user_id': 'tec_0348',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'Laptop comes equipped with advanced cooling system and '
#                       'high refresh rate display, making it built for '
#                       'performance. Great choice for business professionals.',
#   'item_features': 'Touchscreen, Expandable storage, Fast charging',
#   'item_id': 'item_0768',
#   'item_price': np.float64(1612.27),
#   'item_type': 'laptop',
#   'score': 0.9993674159049988,
#   'user_age': np.int64(35),
#   'user_id': 'tec_0348',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'This laptop features AI-powered processor and long '
#                       'battery life, designed for remote workers. It is built '
#                       'for performance, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Touchscreen, Expandable storage',
#   'item_id': 'item_0240',
#   'item_price': np.float64(1018.63),
#   'item_type': 'laptop',
#   'score': 0.9992689490318298,
#   'user_age': np.int64(35),
#   'user_id': 'tec_0348',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'Laptop comes equipped with long battery life and '
#                       'AI-powered processor, making it built for performance. '
#                       'Great choice for gamers.',
#   'item_features': 'USB-C connectivity, Bluetooth 5.0, Fast charging',
#   'item_id': 'item_0690',
#   'item_price': np.float64(830.59),
#   'item_type': 'laptop',
#   'score': 0.9992218017578125,
#   'user_age': np.int64(35),
#   'user_id': 'tec_0348',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'This laptop features advanced cooling system and '
#                       'AI-powered processor, designed for business '
#                       'professionals. It is built for performance, offering '
#                       'reliable performance and user comfort.',
#   'item_features': 'USB-C connectivity, Touchscreen, Expandable storage, '
#                    'Bluetooth 5.0',
#   'item_id': 'item_0153',
#   'item_price': np.float64(473.42),
#   'item_type': 'laptop',
#   'score': 0.9992089867591858,
#   'user_age': np.int64(35),
#   'user_id': 'tec_0348',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'}]
#
#  Recommendations for user: tec_1161
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Laptop comes equipped with long battery life and '
#                       'advanced cooling system, making it built for '
#                       'performance. Great choice for business professionals.',
#   'item_features': 'Fast charging, Expandable storage',
#   'item_id': 'item_0732',
#   'item_price': np.float64(407.81),
#   'item_type': 'laptop',
#   'score': 0.9997192025184631,
#   'user_age': np.int64(30),
#   'user_id': 'tec_1161',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'Laptop comes equipped with advanced cooling system and '
#                       'long battery life, making it built for performance. '
#                       'Great choice for remote workers.',
#   'item_features': 'USB-C connectivity, Bluetooth 5.0, Touchscreen',
#   'item_id': 'item_0631',
#   'item_price': np.float64(285.36),
#   'item_type': 'laptop',
#   'score': 0.9996629953384399,
#   'user_age': np.int64(30),
#   'user_id': 'tec_1161',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'This laptop features AI-powered processor and advanced '
#                       'cooling system, designed for business professionals. It '
#                       'is built for performance, offering reliable performance '
#                       'and user comfort.',
#   'item_features': 'Expandable storage, Touchscreen',
#   'item_id': 'item_0524',
#   'item_price': np.float64(884.74),
#   'item_type': 'laptop',
#   'score': 0.9996541738510132,
#   'user_age': np.int64(30),
#   'user_id': 'tec_1161',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'This laptop features AI-powered processor and high '
#                       'refresh rate display, designed for business '
#                       'professionals. It is built for performance, offering '
#                       'reliable performance and user comfort.',
#   'item_features': 'Expandable storage, Fast charging, USB-C connectivity',
#   'item_id': 'item_0887',
#   'item_price': np.float64(890.66),
#   'item_type': 'laptop',
#   'score': 0.9995903372764587,
#   'user_age': np.int64(30),
#   'user_id': 'tec_1161',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'},
#  {'item_description': 'This laptop features advanced cooling system and '
#                       'AI-powered processor, designed for gamers. It is built '
#                       'for performance, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0849',
#   'item_price': np.float64(483.54),
#   'item_type': 'laptop',
#   'score': 0.9983906745910645,
#   'user_age': np.int64(30),
#   'user_id': 'tec_1161',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'engineering'}]
#
#  Recommendations for user: tec_0145
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for business professionals, this laptop '
#                       'includes AI-powered processor and high refresh rate '
#                       'display. It’s perfect for multitasking and built for '
#                       'high efficiency.',
#   'item_features': 'Touchscreen, Bluetooth 5.0',
#   'item_id': 'item_0001',
#   'item_price': np.float64(852.66),
#   'item_type': 'laptop',
#   'score': 0.5,
#   'user_age': np.int64(25),
#   'user_id': 'tec_0145',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'science'},
#  {'item_description': 'Designed for gamers, this headphones includes long '
#                       'battery life and noise cancellation. It’s ideal for '
#                       'immersive sound and built for high efficiency.',
#   'item_features': 'Bluetooth 5.0, Fast charging, Noise cancellation, Over-ear '
#                    'design',
#   'item_id': 'item_1000',
#   'item_price': np.float64(86.29),
#   'item_type': 'headphones',
#   'score': 0.5,
#   'user_age': np.int64(25),
#   'user_id': 'tec_0145',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'science'},
#  {'item_description': 'Headphones comes equipped with noise cancellation and '
#                       'deep bass, making it great for travel. Great choice for '
#                       'music lovers.',
#   'item_features': 'Fast charging, Bluetooth 5.0, Over-ear design',
#   'item_id': 'item_0041',
#   'item_price': np.float64(92.97),
#   'item_type': 'headphones',
#   'score': 0.5,
#   'user_age': np.int64(25),
#   'user_id': 'tec_0145',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'science'},
#  {'item_description': 'Headphones comes equipped with noise cancellation and '
#                       'long battery life, making it ideal for immersive sound. '
#                       'Great choice for gamers.',
#   'item_features': 'Noise cancellation, Over-ear design, Bluetooth 5.0, Fast '
#                    'charging',
#   'item_id': 'item_0040',
#   'item_price': np.float64(72.86),
#   'item_type': 'headphones',
#   'score': 0.5,
#   'user_age': np.int64(25),
#   'user_id': 'tec_0145',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'science'},
#  {'item_description': 'Designed for business professionals, this laptop '
#                       'includes high refresh rate display and advanced cooling '
#                       'system. It’s built for performance and built for high '
#                       'efficiency.',
#   'item_features': 'USB-C connectivity, Bluetooth 5.0',
#   'item_id': 'item_0039',
#   'item_price': np.float64(342.38),
#   'item_type': 'laptop',
#   'score': 0.5,
#   'user_age': np.int64(25),
#   'user_id': 'tec_0145',
#   'user_personality': 'Tech Enthusiast',
#   'user_profession': 'science'}]
#
#  Personality: Creative Explorer
#
#  Recommendations for user: cre_1936
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'With 4K UHD display and ultra-thin bezel, this monitor '
#                       'is built for high clarity. Perfect for content '
#                       'creators, it delivers top-tier functionality.',
#   'item_features': 'Low blue light, HDMI connectivity, Adjustable stand',
#   'item_id': 'item_0505',
#   'item_price': np.float64(118.19),
#   'item_type': 'monitor',
#   'score': 0.9999873638153076,
#   'user_age': np.int64(35),
#   'user_id': 'cre_1936',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Designed for content creators, this monitor includes '
#                       'HDR10 support and anti-glare coating. It’s built for '
#                       'high clarity and built for high efficiency.',
#   'item_features': 'Adjustable stand, 4K display, Low blue light, HDMI '
#                    'connectivity',
#   'item_id': 'item_0669',
#   'item_price': np.float64(80.0),
#   'item_type': 'monitor',
#   'score': 0.9999867677688599,
#   'user_age': np.int64(35),
#   'user_id': 'cre_1936',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Monitor comes equipped with ultra-thin bezel and 4K UHD '
#                       'display, making it built for high clarity. Great choice '
#                       'for content creators.',
#   'item_features': 'Low blue light, 4K display',
#   'item_id': 'item_0158',
#   'item_price': np.float64(175.18),
#   'item_type': 'monitor',
#   'score': 0.9999861717224121,
#   'user_age': np.int64(35),
#   'user_id': 'cre_1936',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'With ultra-thin bezel and HDR10 support, this monitor '
#                       'is built for high clarity. Perfect for content '
#                       'creators, it delivers top-tier functionality.',
#   'item_features': 'Adjustable stand, Low blue light, HDMI connectivity, 4K '
#                    'display',
#   'item_id': 'item_0085',
#   'item_price': np.float64(111.84),
#   'item_type': 'monitor',
#   'score': 0.9999643564224243,
#   'user_age': np.int64(35),
#   'user_id': 'cre_1936',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Monitor comes equipped with anti-glare coating and '
#                       'ultra-thin bezel, making it built for high clarity. '
#                       'Great choice for productivity setups.',
#   'item_features': 'HDMI connectivity, 4K display, Low blue light, Adjustable '
#                    'stand',
#   'item_id': 'item_0757',
#   'item_price': np.float64(176.38),
#   'item_type': 'monitor',
#   'score': 0.8683326840400696,
#   'user_age': np.int64(35),
#   'user_id': 'cre_1936',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'}]
#
#  Recommendations for user: cre_1872
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'This monitor features anti-glare coating and 4K UHD '
#                       'display, designed for content creators. It is built for '
#                       'high clarity, offering reliable performance and user '
#                       'comfort.',
#   'item_features': '4K display, Adjustable stand',
#   'item_id': 'item_0025',
#   'item_price': np.float64(122.67),
#   'item_type': 'monitor',
#   'score': 0.9999279975891113,
#   'user_age': np.int64(42),
#   'user_id': 'cre_1872',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'business'},
#  {'item_description': 'With 4K UHD display and ultra-thin bezel, this monitor '
#                       'is built for high clarity. Perfect for content '
#                       'creators, it delivers top-tier functionality.',
#   'item_features': 'Low blue light, HDMI connectivity, Adjustable stand',
#   'item_id': 'item_0505',
#   'item_price': np.float64(118.19),
#   'item_type': 'monitor',
#   'score': 0.9999266862869263,
#   'user_age': np.int64(42),
#   'user_id': 'cre_1872',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'business'},
#  {'item_description': 'With ultra-thin bezel and HDR10 support, this monitor '
#                       'is built for high clarity. Perfect for content '
#                       'creators, it delivers top-tier functionality.',
#   'item_features': 'Adjustable stand, Low blue light, HDMI connectivity, 4K '
#                    'display',
#   'item_id': 'item_0085',
#   'item_price': np.float64(111.84),
#   'item_type': 'monitor',
#   'score': 0.9998451471328735,
#   'user_age': np.int64(42),
#   'user_id': 'cre_1872',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'business'},
#  {'item_description': 'Monitor comes equipped with anti-glare coating and '
#                       'ultra-thin bezel, making it built for high clarity. '
#                       'Great choice for productivity setups.',
#   'item_features': 'HDMI connectivity, 4K display, Low blue light, Adjustable '
#                    'stand',
#   'item_id': 'item_0757',
#   'item_price': np.float64(176.38),
#   'item_type': 'monitor',
#   'score': 0.8419750332832336,
#   'user_age': np.int64(42),
#   'user_id': 'cre_1872',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'business'},
#  {'item_description': 'This laptop features high refresh rate display and long '
#                       'battery life, designed for remote workers. It is great '
#                       'for travel, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Expandable storage, Touchscreen, USB-C connectivity, '
#                    'Bluetooth 5.0',
#   'item_id': 'item_0005',
#   'item_price': np.float64(591.65),
#   'item_type': 'laptop',
#   'score': 0.608921229839325,
#   'user_age': np.int64(42),
#   'user_id': 'cre_1872',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'business'}]
#
#  Recommendations for user: cre_1058
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'With 4K UHD display and HDR10 support, this monitor is '
#                       'built for high clarity. Perfect for content creators, '
#                       'it delivers top-tier functionality.',
#   'item_features': 'HDMI connectivity, Low blue light, Adjustable stand, 4K '
#                    'display',
#   'item_id': 'item_0394',
#   'item_price': np.float64(281.75),
#   'item_type': 'monitor',
#   'score': 0.9999866485595703,
#   'user_age': np.int64(29),
#   'user_id': 'cre_1058',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Designed for content creators, this monitor includes '
#                       'anti-glare coating and 4K UHD display. It’s built for '
#                       'high clarity and built for high efficiency.',
#   'item_features': 'Adjustable stand, Low blue light',
#   'item_id': 'item_0466',
#   'item_price': np.float64(137.37),
#   'item_type': 'monitor',
#   'score': 0.9999734163284302,
#   'user_age': np.int64(29),
#   'user_id': 'cre_1058',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Monitor comes equipped with anti-glare coating and '
#                       'ultra-thin bezel, making it built for high clarity. '
#                       'Great choice for productivity setups.',
#   'item_features': 'HDMI connectivity, 4K display, Low blue light, Adjustable '
#                    'stand',
#   'item_id': 'item_0757',
#   'item_price': np.float64(176.38),
#   'item_type': 'monitor',
#   'score': 0.8839293718338013,
#   'user_age': np.int64(29),
#   'user_id': 'cre_1058',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'This laptop features high refresh rate display and long '
#                       'battery life, designed for remote workers. It is great '
#                       'for travel, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Expandable storage, Touchscreen, USB-C connectivity, '
#                    'Bluetooth 5.0',
#   'item_id': 'item_0005',
#   'item_price': np.float64(591.65),
#   'item_type': 'laptop',
#   'score': 0.6311870217323303,
#   'user_age': np.int64(29),
#   'user_id': 'cre_1058',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'},
#  {'item_description': 'Monitor comes equipped with 4K UHD display and '
#                       'anti-glare coating, making it perfect for dual-screen '
#                       'setups. Great choice for productivity setups.',
#   'item_features': '4K display, Adjustable stand, Low blue light',
#   'item_id': 'item_0335',
#   'item_price': np.float64(208.78),
#   'item_type': 'monitor',
#   'score': 0.5,
#   'user_age': np.int64(29),
#   'user_id': 'cre_1058',
#   'user_personality': 'Creative Explorer',
#   'user_profession': 'arts'}]
#
#  Personality: Practical Buyer
#
#  Recommendations for user: pra_1501
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for business professionals, this laptop '
#                       'includes AI-powered processor and high refresh rate '
#                       'display. It’s perfect for multitasking and built for '
#                       'high efficiency.',
#   'item_features': 'Touchscreen, Bluetooth 5.0',
#   'item_id': 'item_0001',
#   'item_price': np.float64(852.66),
#   'item_type': 'laptop',
#   'score': 0.5,
#   'user_age': np.int64(38),
#   'user_id': 'pra_1501',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for gamers, this headphones includes long '
#                       'battery life and noise cancellation. It’s ideal for '
#                       'immersive sound and built for high efficiency.',
#   'item_features': 'Bluetooth 5.0, Fast charging, Noise cancellation, Over-ear '
#                    'design',
#   'item_id': 'item_1000',
#   'item_price': np.float64(86.29),
#   'item_type': 'headphones',
#   'score': 0.5,
#   'user_age': np.int64(38),
#   'user_id': 'pra_1501',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'education'},
#  {'item_description': 'Mouse comes equipped with silent click buttons and '
#                       'ergonomic design, making it ideal for everyday use. '
#                       'Great choice for office use.',
#   'item_features': 'Rechargeable, Compact design, Wireless',
#   'item_id': 'item_0999',
#   'item_price': np.float64(34.57),
#   'item_type': 'mouse',
#   'score': 0.5,
#   'user_age': np.int64(38),
#   'user_id': 'pra_1501',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for home use, this router includes dual-band '
#                       'connectivity and parental controls. It’s built for low '
#                       'latency and built for high efficiency.',
#   'item_features': 'Mesh-ready, Gigabit ports, Parental controls',
#   'item_id': 'item_0998',
#   'item_price': np.float64(116.32),
#   'item_type': 'router',
#   'score': 0.5,
#   'user_age': np.int64(38),
#   'user_id': 'pra_1501',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'education'},
#  {'item_description': 'With HDR10 support and ultra-thin bezel, this monitor '
#                       'is great for streaming. Perfect for content creators, '
#                       'it delivers top-tier functionality.',
#   'item_features': 'HDMI connectivity, Low blue light',
#   'item_id': 'item_0997',
#   'item_price': np.float64(278.44),
#   'item_type': 'monitor',
#   'score': 0.5,
#   'user_age': np.int64(38),
#   'user_id': 'pra_1501',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'education'}]
#
#  Recommendations for user: pra_0987
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for gamers, this mouse includes adjustable DPI '
#                       'and precision tracking. It’s ideal for everyday use and '
#                       'built for high efficiency.',
#   'item_features': 'Wireless, Silent clicks',
#   'item_id': 'item_0679',
#   'item_price': np.float64(68.11),
#   'item_type': 'mouse',
#   'score': 0.9983545541763306,
#   'user_age': np.int64(55),
#   'user_id': 'pra_0987',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'business'},
#  {'item_description': 'With adjustable DPI and silent click buttons, this '
#                       'mouse is ideal for everyday use. Perfect for office '
#                       'use, it delivers top-tier functionality.',
#   'item_features': 'Compact design, Silent clicks, Wireless, Rechargeable',
#   'item_id': 'item_0054',
#   'item_price': np.float64(58.87),
#   'item_type': 'mouse',
#   'score': 0.9966248273849487,
#   'user_age': np.int64(55),
#   'user_id': 'pra_0987',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'business'},
#  {'item_description': 'Designed for gamers, this mouse includes precision '
#                       'tracking and ergonomic design. It’s great for '
#                       'portability and built for high efficiency.',
#   'item_features': 'Silent clicks, Rechargeable, Wireless',
#   'item_id': 'item_0242',
#   'item_price': np.float64(42.45),
#   'item_type': 'mouse',
#   'score': 0.9941380023956299,
#   'user_age': np.int64(55),
#   'user_id': 'pra_0987',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'business'},
#  {'item_description': 'Mouse comes equipped with adjustable DPI and silent '
#                       'click buttons, making it great for portability. Great '
#                       'choice for office use.',
#   'item_features': 'Rechargeable, Compact design, Wireless, Silent clicks',
#   'item_id': 'item_0118',
#   'item_price': np.float64(26.42),
#   'item_type': 'mouse',
#   'score': 0.9934321045875549,
#   'user_age': np.int64(55),
#   'user_id': 'pra_0987',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'business'},
#  {'item_description': 'With ergonomic design and precision tracking, this '
#                       'mouse is great for portability. Perfect for graphic '
#                       'designers, it delivers top-tier functionality.',
#   'item_features': 'Rechargeable, Compact design, Wireless, Silent clicks',
#   'item_id': 'item_0689',
#   'item_price': np.float64(61.56),
#   'item_type': 'mouse',
#   'score': 0.9934042096138,
#   'user_age': np.int64(55),
#   'user_id': 'pra_0987',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'business'}]
#
#  Recommendations for user: pra_0076
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for graphic designers, this mouse includes '
#                       'ergonomic design and silent click buttons. It’s great '
#                       'for portability and built for high efficiency.',
#   'item_features': 'Wireless, Compact design, Rechargeable, Silent clicks',
#   'item_id': 'item_0121',
#   'item_price': np.float64(63.81),
#   'item_type': 'mouse',
#   'score': 0.9994961023330688,
#   'user_age': np.int64(41),
#   'user_id': 'pra_0076',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'law'},
#  {'item_description': 'With adjustable DPI and ergonomic design, this mouse is '
#                       'great for portability. Perfect for gamers, it delivers '
#                       'top-tier functionality.',
#   'item_features': 'Wireless, Rechargeable, Compact design',
#   'item_id': 'item_0871',
#   'item_price': np.float64(41.28),
#   'item_type': 'mouse',
#   'score': 0.998749852180481,
#   'user_age': np.int64(41),
#   'user_id': 'pra_0076',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'law'},
#  {'item_description': 'Designed for graphic designers, this mouse includes '
#                       'silent click buttons and precision tracking. It’s great '
#                       'for portability and built for high efficiency.',
#   'item_features': 'Wireless, Silent clicks, Compact design',
#   'item_id': 'item_0951',
#   'item_price': np.float64(40.1),
#   'item_type': 'mouse',
#   'score': 0.9983344674110413,
#   'user_age': np.int64(41),
#   'user_id': 'pra_0076',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'law'},
#  {'item_description': 'With ergonomic design and precision tracking, this '
#                       'mouse is great for portability. Perfect for gamers, it '
#                       'delivers top-tier functionality.',
#   'item_features': 'Silent clicks, Rechargeable, Compact design, Wireless',
#   'item_id': 'item_0721',
#   'item_price': np.float64(51.34),
#   'item_type': 'mouse',
#   'score': 0.998211145401001,
#   'user_age': np.int64(41),
#   'user_id': 'pra_0076',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'law'},
#  {'item_description': 'Mouse comes equipped with ergonomic design and silent '
#                       'click buttons, making it great for portability. Great '
#                       'choice for gamers.',
#   'item_features': 'Wireless, Silent clicks, Rechargeable',
#   'item_id': 'item_0265',
#   'item_price': np.float64(39.9),
#   'item_type': 'mouse',
#   'score': 0.9979039430618286,
#   'user_age': np.int64(41),
#   'user_id': 'pra_0076',
#   'user_personality': 'Practical Buyer',
#   'user_profession': 'law'}]
#
#  Personality: Performance Seeker
#
#  Recommendations for user: per_0482
# [{'item_description': 'Laptop comes equipped with long battery life and high '
#                       'refresh rate display, making it great for travel. Great '
#                       'choice for remote workers.',
#   'item_features': 'Touchscreen, Expandable storage',
#   'item_id': 'item_0427',
#   'item_price': np.float64(410.57),
#   'item_type': 'laptop',
#   'score': 0.9999994039535522,
#   'user_age': np.int64(25),
#   'user_id': 'per_0482',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'This laptop features advanced cooling system and high '
#                       'refresh rate display, designed for business '
#                       'professionals. It is built for performance, offering '
#                       'reliable performance and user comfort.',
#   'item_features': 'Expandable storage, Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0705',
#   'item_price': np.float64(305.42),
#   'item_type': 'laptop',
#   'score': 0.9999980926513672,
#   'user_age': np.int64(25),
#   'user_id': 'per_0482',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'This laptop features high refresh rate display and long '
#                       'battery life, designed for remote workers. It is great '
#                       'for travel, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Expandable storage, Touchscreen, USB-C connectivity, '
#                    'Bluetooth 5.0',
#   'item_id': 'item_0005',
#   'item_price': np.float64(591.65),
#   'item_type': 'laptop',
#   'score': 0.9999978542327881,
#   'user_age': np.int64(25),
#   'user_id': 'per_0482',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'This laptop features AI-powered processor and long '
#                       'battery life, designed for remote workers. It is built '
#                       'for performance, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Touchscreen, Expandable storage',
#   'item_id': 'item_0240',
#   'item_price': np.float64(1018.63),
#   'item_type': 'laptop',
#   'score': 0.9999918937683105,
#   'user_age': np.int64(25),
#   'user_id': 'per_0482',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for remote workers, this laptop includes '
#                       'AI-powered processor and advanced cooling system. It’s '
#                       'built for performance and built for high efficiency.',
#   'item_features': 'Bluetooth 5.0, USB-C connectivity, Touchscreen, Expandable '
#                    'storage',
#   'item_id': 'item_0231',
#   'item_price': np.float64(461.65),
#   'item_type': 'laptop',
#   'score': 0.999967098236084,
#   'user_age': np.int64(25),
#   'user_id': 'per_0482',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'}]
#
#  Recommendations for user: per_1030
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Laptop comes equipped with long battery life and high '
#                       'refresh rate display, making it great for travel. Great '
#                       'choice for remote workers.',
#   'item_features': 'Touchscreen, Expandable storage',
#   'item_id': 'item_0427',
#   'item_price': np.float64(410.57),
#   'item_type': 'laptop',
#   'score': 0.9999997615814209,
#   'user_age': np.int64(28),
#   'user_id': 'per_1030',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'business'},
#  {'item_description': 'This laptop features advanced cooling system and high '
#                       'refresh rate display, designed for business '
#                       'professionals. It is built for performance, offering '
#                       'reliable performance and user comfort.',
#   'item_features': 'Expandable storage, Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0705',
#   'item_price': np.float64(305.42),
#   'item_type': 'laptop',
#   'score': 0.9999992847442627,
#   'user_age': np.int64(28),
#   'user_id': 'per_1030',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'business'},
#  {'item_description': 'Laptop comes equipped with high refresh rate display '
#                       'and long battery life, making it perfect for '
#                       'multitasking. Great choice for gamers.',
#   'item_features': 'Expandable storage, Fast charging, USB-C connectivity',
#   'item_id': 'item_0420',
#   'item_price': np.float64(687.98),
#   'item_type': 'laptop',
#   'score': 0.9999953508377075,
#   'user_age': np.int64(28),
#   'user_id': 'per_1030',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'business'},
#  {'item_description': 'Designed for remote workers, this laptop includes high '
#                       'refresh rate display and AI-powered processor. It’s '
#                       'built for performance and built for high efficiency.',
#   'item_features': 'USB-C connectivity, Touchscreen, Expandable storage, Fast '
#                    'charging',
#   'item_id': 'item_0020',
#   'item_price': np.float64(328.27),
#   'item_type': 'laptop',
#   'score': 0.999985933303833,
#   'user_age': np.int64(28),
#   'user_id': 'per_1030',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'business'},
#  {'item_description': 'Laptop comes equipped with high refresh rate display '
#                       'and advanced cooling system, making it built for '
#                       'performance. Great choice for business professionals.',
#   'item_features': 'Expandable storage, Touchscreen, USB-C connectivity',
#   'item_id': 'item_0734',
#   'item_price': np.float64(283.92),
#   'item_type': 'laptop',
#   'score': 0.9999464750289917,
#   'user_age': np.int64(28),
#   'user_id': 'per_1030',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'business'}]
#
#  Recommendations for user: per_1015
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for remote workers, this laptop includes high '
#                       'refresh rate display and long battery life. It’s great '
#                       'for travel and built for high efficiency.',
#   'item_features': 'USB-C connectivity, Touchscreen, Expandable storage, Fast '
#                    'charging',
#   'item_id': 'item_0609',
#   'item_price': np.float64(273.32),
#   'item_type': 'laptop',
#   'score': 0.9987972974777222,
#   'user_age': np.int64(31),
#   'user_id': 'per_1015',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'This laptop features long battery life and high refresh '
#                       'rate display, designed for gamers. It is perfect for '
#                       'multitasking, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Fast charging, Expandable storage, Touchscreen',
#   'item_id': 'item_0219',
#   'item_price': np.float64(521.82),
#   'item_type': 'laptop',
#   'score': 0.9985951781272888,
#   'user_age': np.int64(31),
#   'user_id': 'per_1015',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for gamers, this laptop includes advanced '
#                       'cooling system and high refresh rate display. It’s '
#                       'built for performance and built for high efficiency.',
#   'item_features': 'Expandable storage, Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0503',
#   'item_price': np.float64(330.54),
#   'item_type': 'laptop',
#   'score': 0.9981101751327515,
#   'user_age': np.int64(31),
#   'user_id': 'per_1015',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'With long battery life and high refresh rate display, '
#                       'this laptop is perfect for multitasking. Perfect for '
#                       'remote workers, it delivers top-tier functionality.',
#   'item_features': 'Expandable storage, Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0419',
#   'item_price': np.float64(1199.49),
#   'item_type': 'laptop',
#   'score': 0.9977172613143921,
#   'user_age': np.int64(31),
#   'user_id': 'per_1015',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for remote workers, this laptop includes '
#                       'advanced cooling system and long battery life. It’s '
#                       'built for performance and built for high efficiency.',
#   'item_features': 'Expandable storage, Bluetooth 5.0, USB-C connectivity, '
#                    'Touchscreen',
#   'item_id': 'item_0051',
#   'item_price': np.float64(782.15),
#   'item_type': 'laptop',
#   'score': 0.995681643486023,
#   'user_age': np.int64(31),
#   'user_id': 'per_1015',
#   'user_personality': 'Performance Seeker',
#   'user_profession': 'education'}]
#
#  Personality: Budget Conscious
#
#  Recommendations for user: bud_1133
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'Designed for gamers, this headphones includes wireless '
#                       'connectivity and noise cancellation. It’s great for '
#                       'travel and built for high efficiency.',
#   'item_features': 'Noise cancellation, Fast charging, Bluetooth 5.0',
#   'item_id': 'item_0967',
#   'item_price': np.float64(49.19),
#   'item_type': 'headphones',
#   'score': 0.9983124732971191,
#   'user_age': np.int64(26),
#   'user_id': 'bud_1133',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'arts'},
#  {'item_description': 'Headphones comes equipped with deep bass and noise '
#                       'cancellation, making it great for travel. Great choice '
#                       'for commuters.',
#   'item_features': 'Bluetooth 5.0, Fast charging, Noise cancellation, Over-ear '
#                    'design',
#   'item_id': 'item_0569',
#   'item_price': np.float64(40.0),
#   'item_type': 'headphones',
#   'score': 0.9982671737670898,
#   'user_age': np.int64(26),
#   'user_id': 'bud_1133',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'arts'},
#  {'item_description': 'This headphones features deep bass and noise '
#                       'cancellation, designed for music lovers. It is great '
#                       'for travel, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'Fast charging, Noise cancellation, Over-ear design, '
#                    'Bluetooth 5.0',
#   'item_id': 'item_0972',
#   'item_price': np.float64(49.08),
#   'item_type': 'headphones',
#   'score': 0.9976047277450562,
#   'user_age': np.int64(26),
#   'user_id': 'bud_1133',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'arts'},
#  {'item_description': 'With long battery life and noise cancellation, this '
#                       'headphones is great for travel. Perfect for commuters, '
#                       'it delivers top-tier functionality.',
#   'item_features': 'Noise cancellation, Fast charging, Bluetooth 5.0, Over-ear '
#                    'design',
#   'item_id': 'item_0698',
#   'item_price': np.float64(40.0),
#   'item_type': 'headphones',
#   'score': 0.9908368587493896,
#   'user_age': np.int64(26),
#   'user_id': 'bud_1133',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'arts'},
#  {'item_description': 'This laptop features long battery life and advanced '
#                       'cooling system, designed for business professionals. It '
#                       'is built for performance, offering reliable performance '
#                       'and user comfort.',
#   'item_features': 'Fast charging, Bluetooth 5.0, Touchscreen, Expandable '
#                    'storage',
#   'item_id': 'item_0342',
#   'item_price': np.float64(751.33),
#   'item_type': 'laptop',
#   'score': 0.5,
#   'user_age': np.int64(26),
#   'user_id': 'bud_1133',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'arts'}]
#
#  Recommendations for user: bud_1631
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# [{'item_description': 'With ergonomic design and adjustable DPI, this mouse is '
#                       'ideal for everyday use. Perfect for gamers, it delivers '
#                       'top-tier functionality.',
#   'item_features': 'Silent clicks, Rechargeable, Compact design, Wireless',
#   'item_id': 'item_0380',
#   'item_price': np.float64(31.07),
#   'item_type': 'mouse',
#   'score': 0.9966893196105957,
#   'user_age': np.int64(24),
#   'user_id': 'bud_1631',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Laptop comes equipped with long battery life and '
#                       'advanced cooling system, making it great for travel. '
#                       'Great choice for business professionals.',
#   'item_features': 'Fast charging, USB-C connectivity',
#   'item_id': 'item_0197',
#   'item_price': np.float64(427.55),
#   'item_type': 'laptop',
#   'score': 0.9957559704780579,
#   'user_age': np.int64(24),
#   'user_id': 'bud_1631',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for music lovers, this headphones includes '
#                       'deep bass and noise cancellation. It’s great for travel '
#                       'and built for high efficiency.',
#   'item_features': 'Over-ear design, Noise cancellation, Fast charging',
#   'item_id': 'item_0783',
#   'item_price': np.float64(79.13),
#   'item_type': 'headphones',
#   'score': 0.9943781495094299,
#   'user_age': np.int64(24),
#   'user_id': 'bud_1631',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for commuters, this headphones includes '
#                       'wireless connectivity and deep bass. It’s great for '
#                       'travel and built for high efficiency.',
#   'item_features': 'Fast charging, Over-ear design, Noise cancellation',
#   'item_id': 'item_0438',
#   'item_price': np.float64(40.0),
#   'item_type': 'headphones',
#   'score': 0.9934059381484985,
#   'user_age': np.int64(24),
#   'user_id': 'bud_1631',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Headphones comes equipped with wireless connectivity '
#                       'and noise cancellation, making it ideal for immersive '
#                       'sound. Great choice for commuters.',
#   'item_features': 'Bluetooth 5.0, Over-ear design, Noise cancellation, Fast '
#                    'charging',
#   'item_id': 'item_0393',
#   'item_price': np.float64(40.0),
#   'item_type': 'headphones',
#   'score': 0.9930554032325745,
#   'user_age': np.int64(24),
#   'user_id': 'bud_1631',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'}]
#
#  Recommendations for user: bud_0634
# [{'item_description': 'This monitor features anti-glare coating and ultra-thin '
#                       'bezel, designed for content creators. It is built for '
#                       'high clarity, offering reliable performance and user '
#                       'comfort.',
#   'item_features': 'HDMI connectivity, Low blue light, 4K display',
#   'item_id': 'item_0090',
#   'item_price': np.float64(177.62),
#   'item_type': 'monitor',
#   'score': 0.5840734243392944,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0634',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Monitor comes equipped with 4K UHD display and '
#                       'anti-glare coating, making it built for high clarity. '
#                       'Great choice for content creators.',
#   'item_features': '4K display, Low blue light',
#   'item_id': 'item_0169',
#   'item_price': np.float64(136.2),
#   'item_type': 'monitor',
#   'score': 0.5839735269546509,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0634',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'Designed for content creators, this monitor includes '
#                       'anti-glare coating and ultra-thin bezel. It’s built for '
#                       'high clarity and built for high efficiency.',
#   'item_features': 'Adjustable stand, Low blue light',
#   'item_id': 'item_0942',
#   'item_price': np.float64(201.41),
#   'item_type': 'monitor',
#   'score': 0.5741921663284302,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0634',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'With 4K UHD display and ultra-thin bezel, this monitor '
#                       'is built for high clarity. Perfect for content '
#                       'creators, it delivers top-tier functionality.',
#   'item_features': 'Low blue light, HDMI connectivity, Adjustable stand',
#   'item_id': 'item_0505',
#   'item_price': np.float64(118.19),
#   'item_type': 'monitor',
#   'score': 0.5739851593971252,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0634',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'},
#  {'item_description': 'This monitor features anti-glare coating and 4K UHD '
#                       'display, designed for content creators. It is built for '
#                       'high clarity, offering reliable performance and user '
#                       'comfort.',
#   'item_features': '4K display, Adjustable stand',
#   'item_id': 'item_0025',
#   'item_price': np.float64(122.67),
#   'item_type': 'monitor',
#   'score': 0.5721043944358826,
#   'user_age': np.int64(26),
#   'user_id': 'bud_0634',
#   'user_personality': 'Budget Conscious',
#   'user_profession': 'education'}]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Evaluating Recommender Accuracy with Holdout Interactions

# %% [markdown]
# To assess the performance of our recommender, we evaluated its ability to predict real, previously observed interactions using the holdout dataset. This dataset was reserved during training and contains genuine user-item interactions that the model has not seen before, making it ideal for unbiased evaluation.
#
# For each user in the holdout set, we randomly selected one actual interaction and calculated the model's predicted score for that user-item pair using the trained two-tower architecture.
#
# The resulting average predicted score for these true interactions was:
#
# 68.80%
#
# This score indicates the model's confidence in recommending items that users have genuinely engaged with, providing a quantitative measure of accuracy and validating that the model has learned meaningful patterns during training.

# %%
def get_score(user_id, item_id):
    # Encode user and item
    user_idx = user_encoder.transform([user_id])[0]
    item_idx = item_encoder.transform([item_id])[0]

    # Get user and item features
    user_row = users[users['user_id'] == user_id].iloc[0]
    item_row = items[items['item_id'] == item_id].iloc[0]

    user_age_scaled = scaler_age.transform([[user_row['age']]])[0][0]
    item_price_scaled = scaler_price.transform([[item_row['price']]])[0][0]

    # Predict
    prediction = model.predict({
        'user_id': np.array([user_idx]),
        'user_age': np.array([user_age_scaled]),
        'item_id': np.array([item_idx]),
        'item_price': np.array([item_price_scaled])
    }, verbose=0).flatten()[0]

    return float(prediction)

# %%
score = get_score('bud_0002', 'item_0755')
print(f"Predicted score: {score:.4f}")
# Out:
# Predicted score: 0.9996
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
interactions[(interactions['user_id']=='bud_0002') & (interactions['item_id']=='item_0755')]
# Out:
# Empty DataFrame
# Columns: [user_id, item_id, label, age, profession, personality, product_type, description, price, features, user_encoded, item_encoded, age_scaled, price_scaled]
# Index: []

# %%
interactions_holdout[(interactions_holdout['user_id']=='bud_0002') & (interactions_holdout['item_id']=='item_0755')]
# Out:
#          user_id    item_id  label
# 117458  bud_0002  item_0755      1

# %%
from tqdm import tqdm

def evaluate_holdout_one_per_user(holdout_df):
    # Pick one random interaction per user
    sampled = holdout_df.groupby('user_id').sample(n=1, random_state=42).reset_index(drop=True)

    scores = []
    for _, row in tqdm(sampled.iterrows(), total=len(sampled), desc="Scoring one interaction per user"):
        user_id = row['user_id']
        item_id = row['item_id']
        score = get_score(user_id, item_id)
        scores.append(score)

    avg_score = sum(scores) / len(scores)
    #print(f"\n Average predicted score (1 interaction per user): {avg_score:.4f}")
    return avg_score

# %%
avg_one_per_user = evaluate_holdout_one_per_user(interactions_holdout)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8751/10000 [21:51<03:09,  6.60it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8752/10000 [21:51<03:03,  6.80it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8753/10000 [21:51<03:02,  6.84it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8754/10000 [21:51<03:11,  6.50it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8755/10000 [21:51<03:04,  6.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8756/10000 [21:51<03:16,  6.34it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8757/10000 [21:52<03:13,  6.42it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8758/10000 [21:52<03:08,  6.59it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8759/10000 [21:52<03:01,  6.84it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8760/10000 [21:52<03:12,  6.43it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8761/10000 [21:52<03:12,  6.42it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8762/10000 [21:52<03:06,  6.64it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8763/10000 [21:52<03:05,  6.68it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8764/10000 [21:53<03:15,  6.31it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8765/10000 [21:53<03:24,  6.04it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8766/10000 [21:53<03:15,  6.30it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8767/10000 [21:53<03:22,  6.10it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8768/10000 [21:53<03:11,  6.43it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8769/10000 [21:53<03:18,  6.20it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8770/10000 [21:54<03:11,  6.42it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8771/10000 [21:54<03:03,  6.69it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8772/10000 [21:54<02:59,  6.86it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8773/10000 [21:54<02:57,  6.91it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8774/10000 [21:54<02:57,  6.89it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8775/10000 [21:54<02:55,  6.97it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8776/10000 [21:54<03:07,  6.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8777/10000 [21:55<03:05,  6.59it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8778/10000 [21:55<03:00,  6.78it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8779/10000 [21:55<03:09,  6.43it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8780/10000 [21:55<03:02,  6.69it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8781/10000 [21:55<03:04,  6.60it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8782/10000 [21:55<02:59,  6.80it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8783/10000 [21:55<02:54,  6.96it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8784/10000 [21:56<02:53,  7.01it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8785/10000 [21:56<03:06,  6.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8786/10000 [21:56<03:13,  6.28it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8787/10000 [21:56<03:04,  6.57it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8788/10000 [21:56<03:03,  6.60it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8789/10000 [21:56<03:12,  6.29it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8790/10000 [21:57<03:08,  6.41it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8791/10000 [21:57<03:02,  6.61it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8792/10000 [21:57<03:16,  6.14it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8793/10000 [21:57<03:07,  6.45it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8794/10000 [21:57<03:18,  6.07it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8795/10000 [21:57<03:22,  5.95it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8796/10000 [21:58<03:24,  5.88it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8797/10000 [21:58<03:37,  5.54it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8798/10000 [21:58<03:44,  5.34it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8799/10000 [21:58<04:20,  4.61it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8800/10000 [21:59<04:17,  4.66it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8801/10000 [21:59<04:03,  4.93it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8802/10000 [21:59<04:08,  4.82it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8803/10000 [21:59<03:56,  5.06it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8804/10000 [21:59<03:57,  5.03it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8805/10000 [21:59<04:02,  4.92it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8806/10000 [22:00<04:03,  4.89it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8807/10000 [22:00<04:07,  4.82it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8808/10000 [22:00<04:01,  4.94it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8809/10000 [22:00<04:15,  4.66it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8810/10000 [22:01<04:15,  4.65it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8811/10000 [22:01<04:12,  4.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8812/10000 [22:01<04:02,  4.91it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8813/10000 [22:01<03:58,  4.98it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8814/10000 [22:01<03:35,  5.51it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8815/10000 [22:01<03:19,  5.95it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8816/10000 [22:02<03:28,  5.68it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8817/10000 [22:02<03:28,  5.67it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8818/10000 [22:02<03:24,  5.77it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8819/10000 [22:02<03:10,  6.19it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8820/10000 [22:02<03:01,  6.49it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8821/10000 [22:02<03:09,  6.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8822/10000 [22:03<03:13,  6.07it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8823/10000 [22:03<03:07,  6.29it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8824/10000 [22:03<03:13,  6.09it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8825/10000 [22:03<03:04,  6.38it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8826/10000 [22:03<02:57,  6.62it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8827/10000 [22:03<03:05,  6.33it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8828/10000 [22:04<03:08,  6.22it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8829/10000 [22:04<03:06,  6.30it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8830/10000 [22:04<02:57,  6.59it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8831/10000 [22:04<02:53,  6.72it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8832/10000 [22:04<02:46,  7.00it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8833/10000 [22:04<02:47,  6.95it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8834/10000 [22:04<02:44,  7.10it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8835/10000 [22:05<02:56,  6.61it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8836/10000 [22:05<03:09,  6.15it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8837/10000 [22:05<03:03,  6.34it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8838/10000 [22:05<02:56,  6.59it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8839/10000 [22:05<02:50,  6.83it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8840/10000 [22:05<02:46,  6.98it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8841/10000 [22:05<02:58,  6.50it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8842/10000 [22:06<03:06,  6.21it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8843/10000 [22:06<03:05,  6.24it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8844/10000 [22:06<02:57,  6.51it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8845/10000 [22:06<02:53,  6.67it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8846/10000 [22:06<02:51,  6.73it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8847/10000 [22:06<02:47,  6.90it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8848/10000 [22:06<02:43,  7.04it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8849/10000 [22:07<02:55,  6.57it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  88%|████████▊ | 8850/10000 [22:07<02:53,  6.61it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  89%|████████▊ | 8851/10000 [22:07<02:49,  6.77it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  89%|████████▊ | 8852/10000 [22:07<02:46,  6.88it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user:  89%|████████▊ | 8853/10000 [22:07<02:43,  7.00it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9966/10000 [25:12<00:04,  7.03it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9967/10000 [25:12<00:04,  7.19it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9968/10000 [25:12<00:04,  7.25it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9969/10000 [25:12<00:04,  6.77it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9970/10000 [25:13<00:04,  6.37it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9971/10000 [25:13<00:04,  6.15it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9972/10000 [25:13<00:04,  6.45it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9973/10000 [25:13<00:04,  6.74it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9974/10000 [25:13<00:03,  6.79it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9975/10000 [25:13<00:03,  6.43it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9976/10000 [25:14<00:04,  5.99it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9977/10000 [25:14<00:03,  5.88it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9978/10000 [25:14<00:03,  6.16it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9979/10000 [25:14<00:03,  6.07it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9980/10000 [25:14<00:03,  6.42it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9981/10000 [25:14<00:02,  6.71it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9982/10000 [25:14<00:02,  6.35it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9983/10000 [25:15<00:02,  6.58it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9984/10000 [25:15<00:02,  6.82it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9985/10000 [25:15<00:02,  6.89it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9986/10000 [25:15<00:02,  6.90it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9987/10000 [25:15<00:01,  6.98it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9988/10000 [25:15<00:01,  6.53it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9989/10000 [25:16<00:01,  6.25it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9990/10000 [25:16<00:01,  6.06it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9991/10000 [25:16<00:01,  6.35it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9992/10000 [25:16<00:01,  6.14it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9993/10000 [25:16<00:01,  6.38it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9994/10000 [25:16<00:00,  6.66it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9995/10000 [25:16<00:00,  6.90it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9996/10000 [25:17<00:00,  6.83it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9997/10000 [25:17<00:00,  7.07it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9998/10000 [25:17<00:00,  7.06it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|█████████▉| 9999/10000 [25:17<00:00,  6.56it/s]/usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Scoring one interaction per user: 100%|██████████| 10000/10000 [25:17<00:00,  6.59it/s]

# %%
print(f"\n Average recommendation score for actual interactions "
      f"(1 random real interaction per user from holdout): {(avg_one_per_user * 100):.4f}%")
# Out:
#  Average recommendation score for actual interactions (1 random real interaction per user from holdout): 68.7972%
